# %%
import pandas as pd
import numpy as np
import random
import math
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
data = pd.read_csv("wweia_data.csv")
data_category = pd.read_csv("wweia_food_categories_addtl.csv")
# data_norm = pd.read_csv("wweia_data_my_norm2.csv")
updated = data.iloc[:,3:]
updt = data.iloc[:,:3]

# 1st method makes features between -1 to 1
data_norm_changed = updated.apply(lambda iterator: ((iterator - iterator.mean())/iterator.std()).round(2))
data_norm = pd.concat([updt, data_norm_changed], axis ="columns")
data_norm

# 2nd method makes features between 0 to 1
# data_norm_changed = updated.apply(lambda iterator: ((iterator.max() - iterator)/(iterator.max() - iterator.min())).round(2))
# data_norm = pd.concat([updt, data_norm_changed], axis ="columns")
# data_norm

# # 3rd method scaling
# scaler = StandardScaler()
# data_norm = scaler.fit_transform(updated)
# scaled = pd.DataFrame(data_norm)
# scaled.columns = ["protein_kcal","total_lipid_kcal","carbohydrate_kcal","energy_kcal","dietary_fiber_g","calcium_mg","iron_mg","magnesium_mg","phosphorus_mg","potassium_mg","sodium_mg","zinc_mg","copper_mcg","selenium_mcg","Vitamin_A_mg_RAE","Vitamin_E_mg_AT","Vitamin_C_mg","thiamin_mg","riboflavin_mg","niacin_mg","Vitamin_B6_mg","Vitamin_B12_mcg","choline_mg","folate_mcg_DFE"]
# data_norm = pd.concat([updt, scaled], axis ="columns")
# data_norm

# 4th normalizing using sklearn
# normalized = preprocessing.normalize(updated)
# scaled = pd.DataFrame(normalized)
# scaled.columns = ["protein_kcal","total_lipid_kcal","carbohydrate_kcal","energy_kcal","dietary_fiber_g","calcium_mg","iron_mg","magnesium_mg","phosphorus_mg","potassium_mg","sodium_mg","zinc_mg","copper_mcg","selenium_mcg","Vitamin_A_mg_RAE","Vitamin_E_mg_AT","Vitamin_C_mg","thiamin_mg","riboflavin_mg","niacin_mg","Vitamin_B6_mg","Vitamin_B12_mcg","choline_mg","folate_mcg_DFE"]
# data_norm = pd.concat([updt, scaled], axis ="columns")
# data_norm
# Out:
#       fdc_id                               description  wweia_category_code  \
# 0     781082                               Milk, human                 9602
# 1     781083                                 Milk, NFS                 1004
# 2     781084                               Milk, whole                 1002
# 3     781085                   Milk, low sodium, whole                 1002
# 4     781086            Milk, calcium fortified, whole                 1002
# ...      ...                                       ...                  ...
# 8685  789767  Breading or batter as ingredient in food                 9999
# 8686  789768   Wheat bread as ingredient in sandwiches                 9999
# 8687  789769         Sauce as ingredient in hamburgers                 9999
# 8688  789770      Industrial oil as ingredient in food                 9999
# 8689  789771                  Energy drink, sugar free                 7104
#
#       protein_kcal  total_lipid_kcal  carbohydrate_kcal  energy_kcal  \
# 0            -0.84             -0.34              -0.62        -0.80
# 1            -0.56             -0.56              -0.71        -0.94
# 2            -0.57             -0.45              -0.72        -0.86
# 3            -0.58             -0.43              -0.73        -0.86
# 4            -0.57             -0.45              -0.72        -0.86
# ...            ...               ...                ...          ...
# 8685         -0.17             -0.62               0.94         0.15
# 8686          0.48             -0.38               1.21         0.59
# 8687         -0.81              1.38              -0.13         0.65
# 8688         -0.97              8.56              -0.94         5.13
# 8689         -0.94             -0.74              -0.91        -1.28
#
#       dietary_fiber_g  calcium_mg  iron_mg  ...  Vitamin_A_mg_RAE  \
# 0               -0.74       -0.33    -0.45  ...             -0.09
# 1               -0.74        0.45    -0.45  ...             -0.13
# 2               -0.74        0.39    -0.45  ...             -0.16
# 3               -0.74        0.29    -0.44  ...             -0.23
# 4               -0.74        0.39    -0.45  ...             -0.16
# ...               ...         ...      ...  ...               ...
# 8685            -0.11       -0.20     0.24  ...             -0.32
# 8686             1.38        0.82     0.39  ...             -0.35
# 8687            -0.50       -0.45    -0.34  ...             -0.26
# 8688            -0.74       -0.61    -0.45  ...             -0.35
# 8689            -0.74       -0.50    -0.45  ...             -0.35
#
#       Vitamin_E_mg_AT  Vitamin_C_mg  thiamin_mg  riboflavin_mg  niacin_mg  \
# 0               -0.32         -0.11       -0.37          -0.42      -0.55
# 1               -0.33         -0.39       -0.31          -0.00      -0.57
# 2               -0.32         -0.40       -0.29          -0.03      -0.58
# 3               -0.32         -0.35       -0.36          -0.22      -0.59
# 4               -0.32         -0.40       -0.29          -0.03      -0.58
# ...               ...           ...         ...            ...        ...
# 8685            -0.32         -0.40        0.67           0.28       0.19
# 8686            -0.23         -0.39        0.60           0.10       0.63
# 8687             0.27         -0.26       -0.34          -0.20      -0.37
# 8688             3.08         -0.40       -0.41          -0.52      -0.60
# 8689            -0.35         -0.40       -0.35           2.39       1.51
#
#       Vitamin_B6_mg  Vitamin_B12_mcg  choline_mg  folate_mcg_DFE
# 0             -0.47            -0.24       -0.37           -0.30
# 1             -0.40            -0.05       -0.38           -0.30
# 2             -0.41            -0.07       -0.42           -0.30
# 3             -0.41            -0.11       -0.37           -0.30
# 4             -0.41            -0.07       -0.42           -0.30
# ...             ...              ...         ...             ...
# 8685          -0.40            -0.23       -0.25            0.51
# 8686          -0.09            -0.26       -0.24            0.15
# 8687          -0.23            -0.25       -0.28           -0.28
# 8688          -0.50            -0.26       -0.76           -0.32
# 8689           3.13             0.69       -0.77           -0.32
#
# [8690 rows x 27 columns]

# %%
# data_norm = pd.concat([updt, data_norm_changed], axis="columns")
# scaled = pd.DataFrame(data_norm)
# scaled.columns = ["protein_kcal","total_lipid_kcal","carbohydrate_kcal","energy_kcal","dietary_fiber_g","calcium_mg","iron_mg","magnesium_mg","phosphorus_mg","potassium_mg","sodium_mg","zinc_mg","copper_mcg","selenium_mcg","Vitamin_A_mg_RAE","Vitamin_E_mg_AT","Vitamin_C_mg","thiamin_mg","riboflavin_mg","niacin_mg","Vitamin_B6_mg","Vitamin_B12_mcg","choline_mg","folate_mcg_DFE"]
# data_norm = pd.concat([updt, scaled], axis ="columns")
# data_norm

# %%
data_category
# Out:
#      wweia_food_category_code     wweia_food_category_description  \
# 0                        1002                         Milk, whole
# 1                        1004                   Milk, reduced fat
# 2                        1006                        Milk, lowfat
# 3                        1008                        Milk, nonfat
# 4                        1202                Flavored milk, whole
# ..                        ...                                 ...
# 150                      9404       Formula, prepared from powder
# 151                      9406  Formula, prepared from concentrate
# 152                      9602                          Human milk
# 153                      9802     Protein and nutritional powders
# 154                      9999     Not included in a food category
#
#     larger_category                    same_category
# 0             Dairy                             Milk
# 1             Dairy                             Milk
# 2             Dairy                             Milk
# 3             Dairy                             Milk
# 4             Dairy                             Milk
# ..              ...                              ...
# 150           Other                          Formula
# 151           Other                          Formula
# 152           Other                       Human milk
# 153           Other  Protein and nutritional powders
# 154           Other  Not included in a food category
#
# [155 rows x 4 columns]

# %%
categories_range = [0, 14, 35, 82, 91, 105, 155]

# %%
selected = []
print("Select out of these:\n")
i=0
for x in range(6):
    x1 = categories_range[i]
    x2 = categories_range[i+1]
    for j in range(x1,x2):
        print("{} -> {}".format(j, data_category["wweia_food_category_description"][j]))
    i+=1    
    selected.append(int(input())+1)
# Out:
# Select out of these:
#
# 0 -> Milk, whole
# 1 -> Milk, reduced fat
# 2 -> Milk, lowfat
# 3 -> Milk, nonfat
# 4 -> Flavored milk, whole
# 5 -> Flavored milk, reduced fat
# 6 -> Flavored milk, lowfat
# 7 -> Flavored milk, nonfat
# 8 -> Milk shakes and other dairy drinks
# 9 -> Milk substitutes
# 10 -> Cheese
# 11 -> Cottage/ricotta cheese
# 12 -> Yogurt, regular
# 13 -> Yogurt, Greek
# 2
# 14 -> Beef, excludes ground
# 15 -> Ground beef
# 16 -> Pork
# 17 -> Lamb, goat, game
# 18 -> Liver and organ meats
# 19 -> Chicken, whole pieces
# 20 -> Chicken patties, nuggets and tenders
# 21 -> Turkey, duck, other poultry
# 22 -> Fish
# 23 -> Shellfish
# 24 -> Eggs and omelets
# 25 -> Cold cuts and cured meats
# 26 -> Bacon
# 27 -> Frankfurters
# 28 -> Sausages
# 29 -> Beans, peas, legumes
# 30 -> Nuts and seeds
# 31 -> Processed soy products
# 32 -> Meat mixed dishes
# 33 -> Poultry mixed dishes
# 34 -> Seafood mixed dishes
# 22
# 35 -> Rice mixed dishes
# 36 -> Pasta mixed dishes, excludes macaroni and cheese
# 37 -> Macaroni and cheese
# 38 -> Turnovers and other grain-based items
# 39 -> Fried rice and lo/chow mein
# 40 -> Stir-fry and soy-based sauce mixtures
# 41 -> Egg rolls, dumplings, sushi
# 42 -> Burritos and tacos
# 43 -> Nachos
# 44 -> Other Mexican mixed dishes
# 45 -> Pizza
# 46 -> Burgers (single code)
# 47 -> Frankfurter sandwiches (single code)
# 48 -> Chicken/turkey sandwiches (single code)
# 49 -> Egg/breakfast sandwiches (single code)
# 50 -> Other sandwiches (single code)
# 51 -> Cheese sandwiches (single code)
# 52 -> Peanut butter and jelly sanwiches (single code)
# 53 -> Soups
# 54 -> Rice
# 55 -> Pasta, noodles, cooked grains
# 56 -> Yeast breads
# 57 -> Rolls and buns
# 58 -> Bagels and English muffins
# 59 -> Tortillas
# 60 -> Biscuits, muffins, quick breads
# 61 -> Pancakes, waffles, French toast
# 62 -> Ready-to-eat cereal, higher sugar (>21.2g/100g)
# 63 -> Ready-to-eat cereal, lower sugar (=<21.2g/100g)
# 64 -> Oatmeal
# 65 -> Grits and other cooked cereals
# 66 -> Potato chips
# 67 -> Tortilla, corn, other chips
# 68 -> Popcorn
# 69 -> Pretzels/snack mix
# 70 -> Crackers, excludes saltines
# 71 -> Saltine crackers
# 72 -> Cereal bars
# 73 -> Nutrition bars
# 74 -> Cakes and pies
# 75 -> Cookies and brownies
# 76 -> Doughnuts, sweet rolls, pastries
# 77 -> Candy containing chocolate
# 78 -> Candy not containing chocolate
# 79 -> Ice cream and frozen dairy desserts
# 80 -> Pudding
# 81 -> Gelatins, ices, sorbets
# 75
# 82 -> Apples
# 83 -> Bananas
# 84 -> Grapes
# 85 -> Peaches and nectarines
# 86 -> Berries
# 87 -> Citrus fruits
# 88 -> Melons
# 89 -> Dried fruits
# 90 -> Other fruits and fruit salads
# 82
# 91 -> Tomatoes
# 92 -> Carrots
# 93 -> Other red and orange vegetables
# 94 -> Dark green vegetables, excludes lettuce
# 95 -> Lettuce and lettuce salads
# 96 -> String beans
# 97 -> Onions
# 98 -> Corn
# 99 -> Other starchy vegetables
# 100 -> Other vegetables and combinations
# 101 -> Vegetable mixed dishes
# 102 -> White potatoes, baked or boiled
# 103 -> French fries and other fried white potatoes
# 104 -> Mashed potatoes and white potato mixtures
# 92
# 105 -> Citrus juice
# 106 -> Apple juice
# 107 -> Other fruit juice
# 108 -> Vegetable juice
# 109 -> Diet soft drinks
# 110 -> Diet sport and energy drinks
# 111 -> Other diet drinks
# 112 -> Soft drinks
# 113 -> Fruit drinks
# 114 -> Sport and energy drinks
# 115 -> Nutritional beverages
# 116 -> Smoothies and grain drinks
# 117 -> Coffee
# 118 -> Tea
# 119 -> Beer
# 120 -> Wine
# 121 -> Liquor and cocktails
# 122 -> Tap water
# 123 -> Bottled water
# 124 -> Flavored or carbonated water
# 125 -> Enhanced or fortified water
# 126 -> Butter and animal fats
# 127 -> Margarine
# 128 -> Cream cheese, sour cream, whipped cream
# 129 -> Cream and cream substitutes
# 130 -> Mayonnaise
# 131 -> Salad dressings and vegetable oils
# 132 -> Tomato-based condiments
# 133 -> Soy-based condiments
# 134 -> Mustard and other condiments
# 135 -> Olives, pickles, pickled vegetables
# 136 -> Pasta sauces, tomato-based
# 137 -> Dips, gravies, other sauces
# 138 -> Sugars and honey
# 139 -> Sugar substitutes
# 140 -> Jams, syrups, toppings
# 141 -> Baby food: cereals
# 142 -> Baby food: fruit
# 143 -> Baby food: vegetable
# 144 -> Baby food: meat and dinners
# 145 -> Baby food: yogurt
# 146 -> Baby food: snacks and sweets
# 147 -> Baby juice
# 148 -> Baby water
# 149 -> Formula, ready-to-feed
# 150 -> Formula, prepared from powder
# 151 -> Formula, prepared from concentrate
# 152 -> Human milk
# 153 -> Protein and nutritional powders
# 154 -> Not included in a food category
# 117

# %%
# data[data["description"]=="Flavored milk, nonfat"]

# %%
selected
# Out:
# [3, 23, 76, 83, 93, 118]

# %%
header_list = ["wweia_food_category_code","wweia_food_category_description","larger_category","same_category"]
df1 = pd.read_csv('wweia_food_categories_addtl.csv',skiprows=lambda x: x not in selected, names = header_list)

# %%
df1
# Out:
#    wweia_food_category_code wweia_food_category_description larger_category  \
# 0                      1006                    Milk, lowfat           Dairy
# 1                      2402                            Fish         Protein
# 2                      5504            Cookies and brownies           Grain
# 3                      6002                          Apples           Fruit
# 4                      6404                         Carrots       Vegetable
# 5                      7302                          Coffee           Other
#
#           same_category
# 0                  Milk
# 1  Seafood mixed dishes
# 2  Cookies and brownies
# 3                Apples
# 4               Carrots
# 5                Coffee

# %%
df1["wweia_food_category_description"][0]
# Out:
# 'Milk, lowfat'

# %%
def category_code():
    # returns category code of foods selected by user
    return df1["wweia_food_category_code"]

# %%
list_of_categories = category_code().to_list()

# %%
list_of_categories
# Out:
# [1006, 2402, 5504, 6002, 6404, 7302]

# %%
synonims = {1002: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1004: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1006: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1008: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1202: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1204: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1206: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1208: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1402: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1404: {1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404},
 1602: {1602, 1604},
 1604: {1602, 1604},
 1820: {1820, 1822},
 1822: {1820, 1822},
 2002: {2002, 2004},
 2004: {2002, 2004},
 2006: {2006},
 2008: {2008},
 2010: {2010},
 2202: {2202, 2204, 2206, 3004},
 2204: {2202, 2204, 2206, 3004},
 2206: {2202, 2204, 2206, 3004},
 2402: {2402, 2404, 3006},
 2404: {2402, 2404, 3006},
 2502: {2502},
 2602: {2602},
 2604: {2604},
 2606: {2606},
 2608: {2608},
 2802: {2802},
 2804: {2804},
 2806: {2806},
 3002: {3002},
 3004: {2202, 2204, 2206, 3004},
 3006: {2402, 2404, 3006},
 3202: {3202, 4002},
 3204: {3204, 4004},
 3206: {3206},
 3208: {3208},
 3402: {3402},
 3404: {3404},
 3406: {3406},
 3502: {3502},
 3504: {3504},
 3506: {3506},
 3602: {3602},
 3702: {3702},
 3703: {3703, 3704, 3706, 3708, 3720, 3722},
 3704: {3703, 3704, 3706, 3708, 3720, 3722},
 3706: {3703, 3704, 3706, 3708, 3720, 3722},
 3708: {3703, 3704, 3706, 3708, 3720, 3722},
 3720: {3703, 3704, 3706, 3708, 3720, 3722},
 3722: {3703, 3704, 3706, 3708, 3720, 3722},
 3802: {3802},
 4002: {3202, 4002},
 4004: {3204, 4004},
 4202: {4202, 4402},
 4204: {4204},
 4206: {4206},
 4208: {4208},
 4402: {4202, 4402},
 4404: {4404},
 4602: {4602, 4604, 4804},
 4604: {4602, 4604, 4804},
 4802: {4802},
 4804: {4602, 4604, 4804},
 5002: {5002, 5004},
 5004: {5002, 5004},
 5006: {5006},
 5008: {5008},
 5202: {5202, 5204},
 5204: {5202, 5204},
 5402: {5402, 5404},
 5404: {5402, 5404},
 5502: {5502},
 5504: {5504},
 5506: {5506},
 5702: {5702, 5704},
 5704: {5702, 5704},
 5802: {5802},
 5804: {5804},
 5806: {5806},
 6002: {6002},
 6004: {6004},
 6006: {6006},
 6008: {6008},
 6010: {6010},
 6012: {6012},
 6014: {6014},
 6016: {6016},
 6018: {6018},
 6402: {6402},
 6404: {6404},
 6406: {6406},
 6408: {6408},
 6410: {6410},
 6412: {6412},
 6414: {6414},
 6416: {6416},
 6418: {6418},
 6420: {6420},
 6422: {6422},
 6802: {6802, 6804, 6806},
 6804: {6802, 6804, 6806},
 6806: {6802, 6804, 6806},
 7002: {7002, 7004, 7006, 7008},
 7004: {7002, 7004, 7006, 7008},
 7006: {7002, 7004, 7006, 7008},
 7008: {7002, 7004, 7006, 7008},
 7102: {7102, 7104, 7106},
 7104: {7102, 7104, 7106},
 7106: {7102, 7104, 7106},
 7202: {7202},
 7204: {7204},
 7206: {7206},
 7208: {7208},
 7220: {7220},
 7302: {7302},
 7304: {7304},
 7502: {7502},
 7504: {7504},
 7506: {7506},
 7702: {7702, 7704, 7802, 7804},
 7704: {7702, 7704, 7802, 7804},
 7802: {7702, 7704, 7802, 7804},
 7804: {7702, 7704, 7802, 7804},
 8002: {8002},
 8004: {8004},
 8006: {8006, 8008},
 8008: {8006, 8008},
 8010: {8010},
 8012: {8012},
 8402: {8402, 8404, 8406},
 8404: {8402, 8404, 8406},
 8406: {8402, 8404, 8406},
 8408: {8408},
 8410: {8410},
 8412: {8412},
 8802: {8802},
 8804: {8804},
 8806: {8806},
 9002: {9002},
 9004: {9004},
 9006: {9006},
 9008: {9008},
 9010: {9010},
 9012: {9012},
 9202: {9202},
 9204: {9204},
 9402: {9402, 9404, 9406},
 9404: {9402, 9404, 9406},
 9406: {9402, 9404, 9406},
 9602: {9602},
 9802: {9802},
 9999: {9999}}

# %%
new_list = []
for j in list_of_categories:
    categ = synonims[j]
    categ = list(categ)
    new_list.append(categ)
new_list
# Out:
# [[1002, 1004, 1006, 1008, 1202, 1204, 1206, 1208, 1402, 1404],
#  [2402, 2404, 3006],
#  [5504],
#  [6002],
#  [6404],
#  [7302]]

# %%
food_ = []
an_list = []
i = 0
for x in new_list:
    print("category {}".format(i+1))
    for y in x:
        z_ = data_norm.loc[data_norm["wweia_category_code"]==y]
        food_.append(z_)
    data_f = pd.concat(food_)
    if i == 0:
        k = data_f.shape[0]
        print("Total elements=",k)
    elif i==1:
        num = data_f.shape[0]
        m = num - k
#         print(num)
        print("Total elements=",m)
    else:    
        m = data_f.shape[0] - num
        num = data_f.shape[0]
#         print(num)
        print("Total elements=",m)
    i+=1
# Out:
# category 1
# Total elements= 136
# category 2
# Total elements= 554
# category 3
# Total elements= 108
# category 4
# Total elements= 14
# category 5
# Total elements= 35
# category 6
# Total elements= 113

# %%
train_p = input("Enter all possible percentage of dataset to split into traning: ")
train_percent = list(map(int, train_p.split(" ")))
start = int(input("Enter starting Value of k: "))
k_range = int(input("Enter the range of k: "))
mult = int(input("Enter in the multiple of: "))
k = [start+i*mult for i in range(k_range)]
# Out:
# Enter all possible percentage of dataset to split into traning: 60 70 80 90
# Enter starting Value of k: 10
# Enter the range of k: 4
# Enter in the multiple of: 10

# %%
def error(list_food, train_percent, k):
    total_error_list = []
    x = 0
    df = pd.concat(list_food)
    print(df.shape)
    
    for s in train_percent:
        for k_val in k:
            train = int(( train_percent[x] *24 )/100)
            test = 24 - train
            col1_train = 3
            col2_train = train + 3
            col1_test = train + 3
            col2_test = 27

            # finds euclidean distance / similarity
            def euclidean(x, y):
                distances = np.sqrt(np.sum(np.square(y - x), axis=1))
                return distances
            calculations = [] 
            indexes = list(df.index)
            # finding similarity / distance from 1 element to all the other elements
            for i in indexes:
                selected1 = df.loc[df["description"]==df["description"][i]]
                selected = selected1[selected1.columns[col1_train:col2_train]]
                remaining = df[df.columns[col1_train:col2_train]]
                selected_test = selected1[selected1.columns[col1_test:col2_test]]
                remaining_test = df[df.columns[col1_test:col2_test]]
                selected = np.array(selected)
                remaining = np.array(remaining)
                z = euclidean(selected, remaining)
                calculations.append(z)

            # list of k nearest neighbors
            list3 = []
            for i in range(len(df)):
                list3.append(sorted(list(enumerate(calculations[i])), key = lambda x:x[1])[0:k_val+1]) 
            
            # Finding percentage error
            error_list = []
            error = 0
            rms = 0
            mean_absolute = 0
            mean_abs2 = 0
            MS = 0
            for i in range(len(df)):
                list2 = pd.DataFrame(list3[i])
                index_of_elem = list2[0].tolist()
                data_test = data_norm[data_norm.columns[col1_test:col2_test]]
                
                # forming a dataset of K nearest elements:
                new2 = []
                for z in index_of_elem:
                    new2.append(data_test.iloc[z])
                selected_D_test = pd.DataFrame(new2)
                avg = selected_D_test.mean()
                actual = data_norm[data_norm.columns[col1_test:col2_test]]
                act = actual.iloc[i]
                act_mean = act.mean()
                avg_mean = avg.mean()
                first = abs(act - avg)
                second = abs(act_mean - avg_mean)
                mean_abs2 += first
                mean_absolute += second
                square = first**2
                rms += square
                sqaured_mean = square.mean()
                MS += sqaured_mean
                err = first.mean()
                error += err
                error_list.append(err)
            rms_mean = rms.mean()
            RMS = math.sqrt(rms_mean)
            error_mean = (error/len(df))*100
            MAE_1 = mean_absolute/len(df)
            MAE_2 = mean_abs2.mean()
            Mean_sq_err = (MS/len(df))*100

            print("The total error for k = {} with training split of {}% is : {:.2f}%".format(k_val,s,error_mean))
#             print("Mean Square Error 1: {:.2f}".format(rms_mean))
#             print("Mean Square Error 2: {:.2f}%".format(Mean_sq_err))
#             print("Root Mean squared error = {:.2f}".format(RMS))
#             print("Mean absolute error_1 = {:.2f}".format(MAE_1))
#             print("Mean absolute error_2 = {:.2f}".format(MAE_2))
            print("------------------------")
        x+=1
    return list3

# %%
food = []
answer = []
i = 1
for x in new_list:
    print("Errors for clusture {}---".format(i))
    for y in x:
        z = data_norm.loc[data_norm["wweia_category_code"]==y]
        food.append(z)
    i+=1
    ans = error(food,train_percent,k)
    answer.append(ans)
    food = []
# Out:
# Errors for clusture 1---
# (136, 27)
# The total error for k = 10 with training split of 60% is : 7.46%
# ------------------------
# The total error for k = 20 with training split of 60% is : 7.79%
# ------------------------
# The total error for k = 30 with training split of 60% is : 7.55%
# ------------------------
# The total error for k = 40 with training split of 60% is : 7.34%
# ------------------------
# The total error for k = 10 with training split of 70% is : 6.87%
# ------------------------
# The total error for k = 20 with training split of 70% is : 7.35%
# ------------------------
# The total error for k = 30 with training split of 70% is : 7.07%
# ------------------------
# The total error for k = 40 with training split of 70% is : 6.79%
# ------------------------
# The total error for k = 10 with training split of 80% is : 7.45%
# ------------------------
# The total error for k = 20 with training split of 80% is : 7.96%
# ------------------------
# The total error for k = 30 with training split of 80% is : 7.56%
# ------------------------
# The total error for k = 40 with training split of 80% is : 7.10%
# ------------------------
# The total error for k = 10 with training split of 90% is : 8.31%
# ------------------------
# The total error for k = 20 with training split of 90% is : 8.64%
# ------------------------
# The total error for k = 30 with training split of 90% is : 8.34%
# ------------------------
# The total error for k = 40 with training split of 90% is : 8.14%
# ------------------------
# Errors for clusture 2---
# (554, 27)
# The total error for k = 10 with training split of 60% is : 10.79%
# ------------------------
# The total error for k = 20 with training split of 60% is : 12.85%
# ------------------------
# The total error for k = 30 with training split of 60% is : 13.12%
# ------------------------
# The total error for k = 40 with training split of 60% is : 13.28%
# ------------------------
# The total error for k = 10 with training split of 70% is : 10.34%
# ------------------------
# The total error for k = 20 with training split of 70% is : 12.52%
# ------------------------
# The total error for k = 30 with training split of 70% is : 12.77%
# ------------------------
# The total error for k = 40 with training split of 70% is : 12.94%
# ------------------------
# The total error for k = 10 with training split of 80% is : 9.19%
# ------------------------
# The total error for k = 20 with training split of 80% is : 11.10%
# ------------------------
# The total error for k = 30 with training split of 80% is : 11.14%
# ------------------------
# The total error for k = 40 with training split of 80% is : 11.17%
# ------------------------
# The total error for k = 10 with training split of 90% is : 9.48%
# ------------------------
# The total error for k = 20 with training split of 90% is : 11.13%
# ------------------------
# The total error for k = 30 with training split of 90% is : 11.44%
# ------------------------
# The total error for k = 40 with training split of 90% is : 11.63%
# ------------------------
# Errors for clusture 3---
# (108, 27)
# The total error for k = 10 with training split of 60% is : 7.39%
# ------------------------
# The total error for k = 20 with training split of 60% is : 7.32%
# ------------------------
# The total error for k = 30 with training split of 60% is : 7.26%
# ------------------------
# The total error for k = 40 with training split of 60% is : 7.42%
# ------------------------
# The total error for k = 10 with training split of 70% is : 6.82%
# ------------------------
# The total error for k = 20 with training split of 70% is : 6.73%
# ------------------------
# The total error for k = 30 with training split of 70% is : 6.82%
# ------------------------
# The total error for k = 40 with training split of 70% is : 6.73%
# ------------------------
# The total error for k = 10 with training split of 80% is : 7.05%
# ------------------------
# The total error for k = 20 with training split of 80% is : 6.90%
# ------------------------
# The total error for k = 30 with training split of 80% is : 6.91%
# ------------------------
# The total error for k = 40 with training split of 80% is : 6.88%
# ------------------------
# The total error for k = 10 with training split of 90% is : 8.53%
# ------------------------
# The total error for k = 20 with training split of 90% is : 8.44%
# ------------------------
# The total error for k = 30 with training split of 90% is : 8.48%
# ------------------------
# The total error for k = 40 with training split of 90% is : 8.57%
# ------------------------
# Errors for clusture 4---
# (14, 27)
# The total error for k = 10 with training split of 60% is : 2.84%
# ------------------------
# The total error for k = 20 with training split of 60% is : 2.89%
# ------------------------
# The total error for k = 30 with training split of 60% is : 2.89%
# ------------------------
# The total error for k = 40 with training split of 60% is : 2.89%
# ------------------------
# The total error for k = 10 with training split of 70% is : 2.80%
# ------------------------
# The total error for k = 20 with training split of 70% is : 2.89%
# ------------------------
# The total error for k = 30 with training split of 70% is : 2.89%
# ------------------------
# The total error for k = 40 with training split of 70% is : 2.89%
# ------------------------
# The total error for k = 10 with training split of 80% is : 1.33%
# ------------------------
# The total error for k = 20 with training split of 80% is : 1.41%
# ------------------------
# The total error for k = 30 with training split of 80% is : 1.41%
# ------------------------
# The total error for k = 40 with training split of 80% is : 1.41%
# ------------------------
# The total error for k = 10 with training split of 90% is : 1.72%
# ------------------------
# The total error for k = 20 with training split of 90% is : 1.82%
# ------------------------
# The total error for k = 30 with training split of 90% is : 1.82%
# ------------------------
# The total error for k = 40 with training split of 90% is : 1.82%
# ------------------------
# Errors for clusture 5---
# (35, 27)
# The total error for k = 10 with training split of 60% is : 5.07%
# ------------------------
# The total error for k = 20 with training split of 60% is : 5.21%
# ------------------------
# The total error for k = 30 with training split of 60% is : 5.38%
# ------------------------
# The total error for k = 40 with training split of 60% is : 5.69%
# ------------------------
# The total error for k = 10 with training split of 70% is : 5.54%
# ------------------------
# The total error for k = 20 with training split of 70% is : 5.31%
# ------------------------
# The total error for k = 30 with training split of 70% is : 5.32%
# ------------------------
# The total error for k = 40 with training split of 70% is : 5.65%
# ------------------------
# The total error for k = 10 with training split of 80% is : 4.93%
# ------------------------
# The total error for k = 20 with training split of 80% is : 4.80%
# ------------------------
# The total error for k = 30 with training split of 80% is : 4.82%
# ------------------------
# The total error for k = 40 with training split of 80% is : 5.24%
# ------------------------
# The total error for k = 10 with training split of 90% is : 7.25%
# ------------------------
# The total error for k = 20 with training split of 90% is : 6.98%
# ------------------------
# The total error for k = 30 with training split of 90% is : 6.88%
# ------------------------
# The total error for k = 40 with training split of 90% is : 7.58%
# ------------------------
# Errors for clusture 6---
# (113, 27)
# The total error for k = 10 with training split of 60% is : 7.27%
# ------------------------
# The total error for k = 20 with training split of 60% is : 7.17%
# ------------------------
# The total error for k = 30 with training split of 60% is : 7.28%
# ------------------------
# The total error for k = 40 with training split of 60% is : 7.40%
# ------------------------
# The total error for k = 10 with training split of 70% is : 6.86%
# ------------------------
# The total error for k = 20 with training split of 70% is : 6.71%
# ------------------------
# The total error for k = 30 with training split of 70% is : 6.65%
# ------------------------
# The total error for k = 40 with training split of 70% is : 6.71%
# ------------------------
# The total error for k = 10 with training split of 80% is : 7.33%
# ------------------------
# The total error for k = 20 with training split of 80% is : 7.10%
# ------------------------
# The total error for k = 30 with training split of 80% is : 7.01%
# ------------------------
# The total error for k = 40 with training split of 80% is : 7.12%
# ------------------------
# The total error for k = 10 with training split of 90% is : 8.69%
# ------------------------
# The total error for k = 20 with training split of 90% is : 8.55%
# ------------------------
# The total error for k = 30 with training split of 90% is : 8.51%
# ------------------------
# The total error for k = 40 with training split of 90% is : 8.68%
# ------------------------

# %%
k_v = int(input("Enter the Final k-value "))
splitting = int(input("Enter the final percentage splitting of dataset "))
# Out:
# Enter the Final k-value 20
# Enter the final percentage splitting of dataset 70

# %%
def Select():
# 
    final = []
    new_indexes = list(df3.index)
    print(df3.shape)
    randm = []
    for b in range(10):
        randm.append(random.choice(new_indexes))

    # 
    user_sel = []
    print("select among these :")
    for x in randm:
        print("{}   -> {}".format(x, data["description"][x]))
    z = input("enter ")    
    user_sel = list(map(int, z.split(" ")))
    return user_sel

# %%
# food2 = []
select_user = []
final = []
check = []
for x in new_list:
    for y in x:
        z = data.loc[data["wweia_category_code"]==y]
        food2.append(z)
    df3 = pd.concat(food2)
    check.append(df3)
    select_user.append(food2)
    final.append(Select())
    food2 = []
# Out:
# (408, 27)
# select among these :
# 183   -> Eggnog, regular
# 146   -> Chocolate milk, made from syrup, NS as to type of milk
# 150   -> Chocolate milk, made from syrup with fat free milk
# 117   -> Hot chocolate / Cocoa, ready to drink, made with nonfat milk
# 142   -> Chocolate milk, made from no sugar added dry mix with reduced fat milk (Nesquik)
# 173   -> Hot chocolate / Cocoa, made with no sugar added dry mix and low fat milk
# 5   -> Milk, calcium fortified, low fat (1%)
# 125   -> Chocolate milk, made from dry mix with low fat milk
# 122   -> Chocolate milk, made from dry mix, NS as to type of milk
# 184   -> Eggnog, lowfat / light
# enter 173
# (554, 27)
# select among these :
# 1629   -> Whiting, coated, fried, made with butter
# 1740   -> Shrimp, coated, baked or broiled, made with cooking spray
# 1451   -> Herring, baked or broiled, fat added in cooking
# 2800   -> Shrimp gumbo
# 1534   -> Salmon, raw
# 1617   -> Whiting, cooked, NS as to cooking method
# 1359   -> Catfish, baked or broiled, made with margarine
# 1619   -> Whiting, baked or broiled, made with butter
# 1426   -> Haddock, coated, baked or broiled, fat not added in cooking
# 1623   -> Whiting, coated, baked or broiled, made with oil
# enter 1534
# (108, 27)
# select among these :
# 3746   -> Cookie, brownie, NS as to icing
# 4079   -> Crackers, Cuban
# 3782   -> Cookie, ladyfinger
# 3799   -> Cookie, oatmeal, with chocolate and peanut butter, no bake
# 3779   -> Cookie, cone shell, ice cream type, wafer or cake
# 3769   -> Cookie, chocolate and vanilla sandwich
# 3794   -> Cookie, oatmeal, with raisins
# 3801   -> Cookie, peanut butter, with chocolate
# 3755   -> Cookie, chocolate chip, reduced fat
# 3810   -> Cookie, rum ball, no bake
# enter 3769
# (14, 27)
# select among these :
# 5552   -> Applesauce, stewed apples, with sugar
# 5552   -> Applesauce, stewed apples, with sugar
# 5559   -> Apple rings, fried
# 5555   -> Apple, cooked or canned, with syrup
# 5558   -> Apple, baked, with sugar
# 5732   -> Apple, candied
# 5553   -> Applesauce, stewed apples, sweetened with low calorie sweetener
# 5559   -> Apple rings, fried
# 5732   -> Apple, candied
# 5552   -> Applesauce, stewed apples, with sugar
# enter 5732
# (35, 27)
# select among these :
# 6463   -> Carrots, cooked, from frozen, made with margarine
# 6446   -> Carrots, cooked, from canned, NS as to fat added in cooking
# 6461   -> Carrots, cooked, from frozen, made with oil
# 6474   -> Carrots, cooked, from canned, glazed
# 6466   -> Carrots, cooked, from canned, made with margarine
# 6452   -> Carrots, cooked, NS as to form, made with butter
# 6479   -> Carrots, canned, low sodium, NS as to fat added in cooking
# 6440   -> Carrots, raw
# 6473   -> Carrots, cooked, from frozen, glazed
# 6480   -> Carrots, canned, low sodium, fat not added in cooking
# enter 6479
# (113, 27)
# select among these :
# 8314   -> Coffee, Iced Latte, flavored
# 8311   -> Coffee, Iced Latte
# 8303   -> Frozen mocha coffee drink, decaffeinated, nonfat
# 8280   -> Frozen coffee drink, with non-dairy milk
# 8274   -> Coffee, Latte, decaffeinated, with non-dairy milk
# 8257   -> Coffee, Turkish
# 8320   -> Coffee, Iced Latte, decaffeinated, flavored
# 8338   -> Coffee, mocha, instant, pre-lightened and pre-sweetened with low calorie sweetener, reconstituted
# 8264   -> Coffee, cafe con leche
# 8341   -> Coffee, mocha, instant, decaffeinated, pre-lightened and pre-sweetened with low calorie sweetener, reconstituted
# enter 8314

# %%
print("User selected:\n")
for x in final:
    for y in x:
        print(data["description"][y])
# Out:
# User selected:
#
# Hot chocolate / Cocoa, made with no sugar added dry mix and low fat milk
# Salmon, raw
# Cookie, chocolate and vanilla sandwich
# Apple, candied
# Carrots, canned, low sodium, NS as to fat added in cooking
# Coffee, Iced Latte, flavored

# %%
gender = input("Are you a MALE or FEMALE: ")
weight = int(input("Enter your Weight in KG: "))
height = int(input("Enter your Height in CM: "))
age = int(input("Enter your age: "))

bmi = weight/((height/100)**2) 

def BMI_cal(bmi):
    #conditions
    print("Your body mass index is: {:.2f}".format(bmi))
    if ( bmi < 16):
        print("Acoording to your BMI, you are Severely Underweight")

    elif ( bmi >= 16 and bmi < 18.5):
        print("Acoording to your BMI, you are Underweight")

    elif ( bmi >= 18.5 and bmi < 25):
        print("Acoording to your BMI, you are Healthy")
        
    elif ( bmi >= 25 and bmi < 30):
        print("Acoording to your BMI, you are Overweight")
        
    elif ( bmi >=30):
        print("Acoording to your BMI, you are Severely Overweight")

        
BMI_cal(bmi)
# Out:
# Are you a MALE or FEMALE: MALE
# Enter your Weight in KG: 70
# Enter your Height in CM: 175
# Enter your age: 22
# Your body mass index is: 22.86
# Acoording to your BMI, you are Healthy

# %%
# Calories acc to BMI
# for men
if gender == "MALE":
    BMR_men = 88.362 + (13.397 * weight) + (4.799 * height) - (5.677 * age)
    # Daily kilocalories needed 
    cal = int(BMR_men * 1.2)
    print("Total Calories needed = {} Kcal/day".format(cal))
# for women
else:
    BMR_women = 447.593 + (9.247 * weight) + (3.098 * height) - (4.330 * age)
    # Daily kilocalories needed 
    cal = int(BMR_women * 1.2)
    print("Total Calories needed = {} Kcal/day".format(cal))
# Out:
# Total Calories needed = 2089 Kcal/day

# %%
cal_per_cat = cal/6
cal_per_cat
# Out:
# 348.1666666666667

# %%
for i in k:
    k_value = i
# k_value

# %%
def recommend_1(k):
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.neighbors import NearestNeighbors
    
    k_value = k
    
    tfidf = TfidfVectorizer(stop_words="english")
    vectors = tfidf.fit_transform(data["description"]).toarray()
    knn = NearestNeighbors(n_neighbors=k_value, algorithm='brute', metric='cosine')
    knn.fit(vectors)


    def recommend(index):
        calories = []
        energy = 0
        remaining = cal_per_cat
        # Finding the index of the input recipe
        recipe_index = index
        _, indices = knn.kneighbors(vectors[recipe_index].reshape(1,-1))
        # Printing only the top k most similar recipes
        for i in indices[0][1:15]:
            if energy < cal_per_cat:
                if data.iloc[i].energy_kcal < remaining: 
                    print("{}, -- calories = {} Kcal".format(data.iloc[i].description, data.iloc[i].energy_kcal))
                    calories.append(data.iloc[i].energy_kcal)
                    energy += data.iloc[i].energy_kcal
                    remaining = cal_per_cat - energy
        print("\nTotal calorie: {} Kcal".format(energy))
        print("--------------------")
        return np.sum(calories)


    # Testing the recommendation function
    total_cal = []
    print("THE RECOMMENDED FOODS ARE\n")
    for item in final:
        energy = recommend(item)
        total_cal.append(energy)

    total_energy = np.sum(total_cal)
    error = abs(total_energy - cal)/cal
#     print("error",error)
    b = i
    while error > .15:
        b+=1
        print("{}, -- calories = {} Kcal".format(data.iloc[b].description, data.iloc[b].energy_kcal))
        total_energy += data.iloc[b].energy_kcal
        error = abs(total_energy - cal)/cal
    print("-------------")
    print("The total calories of the recommended food ",total_energy,"Kcal")
    print("Error percentage between calories actually needed and recommended calories = {:.2f}%".format(error*100))

# %%
def recommend_2(cal_per_categ,split,k):
    
    def euclidean(x, y):
        distances = np.sqrt(np.sum(np.square(y - x), axis=1))
        return distances
    # 
    list5 = []
    for x in range(len(final)):
        for y in final[x]:
            list5.append(y)
    #
    total_energy = []
    for item_index in list5:
        remain = cal_per_categ
        total_cal = 0
        energy = 0
        x = item_index
        select = data.loc[data["description"]==data["description"][x]]
        selected = select[select.columns[3:split+3]]
        sel = np.array(selected)
        remaining = data[data.columns[3:split+3]]
        re = np.array(remaining)
        distance = euclidean(sel, re)
        # recommending top K 
        recommend = sorted(list(enumerate(distance)), key = lambda x:x[1])[0:k]
        for i in range(len(recommend)):
            x = int(recommend[i][0])
            food = data.iloc[x]
            if energy < cal_per_categ:
                if int(food.energy_kcal) < remain:
                    print("{}, -- calories = {} Kcal".format(food.description, food.energy_kcal))
                    energy += int(food.energy_kcal)
                    total_cal = energy
                    remain = cal_per_categ - energy

        total_energy.append(total_cal)
        print("\nTotal calorie: {} Kcal".format(total_cal))
        print("------------------")

    
    total_ = np.sum(total_energy)
    error = abs(total_ - cal)/cal
#     print("error",error)
    b = x
    while error > .15:
        b+=1
        food = data.iloc[b]
        print("{}, -- calories = {} Kcal".format(food.description, food.energy_kcal))
        total_+= food.energy_kcal
        error = abs(total_ - cal)/cal
    print("----------")
    print("The total calories of the recommended food ",total_,"Kcal")
    print("Error percentage between calories actually needed and recommended calories = {:.2f}%".format(error*100))

# %%
recommend_1(k_v)
# Out:
# THE RECOMMENDED FOODS ARE
#
# Hot chocolate / Cocoa, made with dry mix and low fat milk, -- calories = 89 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and whole milk, -- calories = 86 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and reduced fat milk, -- calories = 76 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and fat free milk, -- calories = 62 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and water, -- calories = 31 Kcal
#
# Total calorie: 344 Kcal
# --------------------
# Salmon, canned, -- calories = 137 Kcal
# Salmon, smoked, -- calories = 117 Kcal
#
# Total calorie: 254 Kcal
# --------------------
# Pie, vanilla cream, -- calories = 278 Kcal
#
# Total calorie: 278 Kcal
# --------------------
# Sweet potato, candied, -- calories = 178 Kcal
# Apple, fried, -- calories = 138 Kcal
#
# Total calorie: 316 Kcal
# --------------------
# Carrots, canned, low sodium, fat not added in cooking, -- calories = 23 Kcal
# Carrots, canned, low sodium, fat added in cooking, NS as to type of fat, -- calories = 53 Kcal
# Peas, green, canned, low sodium, NS as to fat added in cooking, -- calories = 100 Kcal
# Carrots, canned, low sodium, made with butter, -- calories = 55 Kcal
# Beets, canned, low sodium, NS as to fat added in cooking, -- calories = 60 Kcal
# Carrots, canned, low sodium, made with margarine, -- calories = 50 Kcal
#
# Total calorie: 341 Kcal
# --------------------
# Coffee, Iced Latte, decaffeinated, flavored, -- calories = 40 Kcal
# Coffee, Iced Latte, -- calories = 27 Kcal
# Coffee, Iced Latte, nonfat, flavored, -- calories = 32 Kcal
# Coffee, Latte, flavored, -- calories = 54 Kcal
# Coffee, Iced Latte, decaffeinated, nonfat, flavored, -- calories = 32 Kcal
# Coffee, Iced Latte, decaffeinated, -- calories = 27 Kcal
# Coffee, Iced Latte, with non-dairy milk, flavored, -- calories = 35 Kcal
# Coffee, Iced Latte, nonfat, -- calories = 19 Kcal
# Coffee, Latte, decaffeinated, flavored, -- calories = 55 Kcal
# Coffee, Iced Latte, decaffeinated, nonfat, -- calories = 19 Kcal
#
# Total calorie: 340 Kcal
# --------------------
# -------------
# The total calories of the recommended food  1873 Kcal
# Error percentage between calories actually needed and recommended calories = 10.34%

# %%
recommend_2(cal_per_cat,splitting, k_v)
# Out:
# Hot chocolate / Cocoa, made with no sugar added dry mix and low fat milk, -- calories = 69 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and fat free milk, -- calories = 62 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and reduced fat milk, -- calories = 76 Kcal
# Hot chocolate / Cocoa, made with no sugar added dry mix and whole milk, -- calories = 86 Kcal
#
# Total calorie: 293 Kcal
# ------------------
# Salmon, raw, -- calories = 127 Kcal
# Mullet, raw, -- calories = 117 Kcal
# Halibut, raw, -- calories = 91 Kcal
#
# Total calorie: 335 Kcal
# ------------------
#
# Total calorie: 0 Kcal
# ------------------
# Apple, candied, -- calories = 129 Kcal
# Sherbet, all flavors, -- calories = 144 Kcal
#
# Total calorie: 273 Kcal
# ------------------
# Carrots, canned, low sodium, NS as to fat added in cooking, -- calories = 53 Kcal
# Carrots, canned, low sodium, fat added in cooking, NS as to type of fat, -- calories = 53 Kcal
# Carrots, canned, low sodium, made with butter, -- calories = 55 Kcal
# Carrots, canned, low sodium, made with margarine, -- calories = 50 Kcal
# Carrots, canned, low sodium, made with oil, -- calories = 59 Kcal
# Carrots, raw, -- calories = 41 Kcal
# Pumpkin, cooked, from canned, fat not added in cooking, -- calories = 34 Kcal
#
# Total calorie: 345 Kcal
# ------------------
# Coffee, Iced Latte, flavored, -- calories = 39 Kcal
# Coffee, Iced Latte, decaffeinated, flavored, -- calories = 40 Kcal
# Coffee, Iced Latte, nonfat, flavored, -- calories = 32 Kcal
# Coffee, Iced Latte, decaffeinated, nonfat, flavored, -- calories = 32 Kcal
# Coffee, Cappuccino, decaffeinated, -- calories = 27 Kcal
# Coffee, Cappuccino, -- calories = 27 Kcal
# Coffee, Iced Latte, decaffeinated, -- calories = 27 Kcal
# Coffee, Iced Latte, -- calories = 27 Kcal
# Coffee, Iced Cafe Mocha, -- calories = 50 Kcal
# Coffee, Iced Cafe Mocha, nonfat, -- calories = 43 Kcal
#
# Total calorie: 344 Kcal
# ------------------
# Frozen coffee drink, decaffeinated, with non-dairy milk, -- calories = 64 Kcal
# Frozen coffee drink, decaffeinated, with whipped cream , -- calories = 81 Kcal
# Frozen coffee drink, decaffeinated, nonfat, with whipped cream , -- calories = 75 Kcal
# ----------
# The total calories of the recommended food  1810 Kcal
# Error percentage between calories actually needed and recommended calories = 13.36%
